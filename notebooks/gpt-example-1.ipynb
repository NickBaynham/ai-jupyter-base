# %% [markdown]
# ### Example 1
# Using input+instructions

# %%
from jupyter_base import OpenAIClient

# %%
client = OpenAIClient()

response = client.responses.create(
    model="gpt-4.1-mini",
    instructions="You are a helpful assistant that explains things clearly and concisely.",
    input="Explain how neural networks work in simple terms."
)

print(response.output[0].content[0].text)
# Out:
# Sure! Think of a neural network like a simplified model of how the brain works. It’s made up of layers of tiny units called neurons.
#
# Here’s how it works in simple steps:
#
# 1. **Input:** The network takes some information, like a picture or numbers.
# 2. **Neurons and Layers:** This information is passed through many layers. Each layer has neurons that look at the data and do simple calculations.
# 3. **Connections and Weights:** Each connection between neurons has a “weight” that tells how important that connection is.
# 4. **Processing:** Neurons add up the information coming in, multiply by these weights, and then decide if they should “fire” (send their signal forward).
# 5. **Output:** After going through all the layers, the network produces an output, like recognizing a cat in a photo or predicting a number.
# 6. **Learning:** The network learns by adjusting the weights based on how wrong its output was, improving over time.
#
# So, a neural network is like a big system of simple decision points that work together to understand complex information!
