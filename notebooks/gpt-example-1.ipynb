# %% [markdown]
# ### Example 1
# Using input+instructions

# %%
from jupyter_base import OpenAIClient

# %%
client = OpenAIClient()

response = client.responses.create(
    model="gpt-4.1-mini",
    instructions="You are a helpful assistant that explains things clearly and concisely.",
    input="Explain how neural networks work in simple terms."
)

print(response.output[0].content[0].text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 client = OpenAIClient()
# ----> 3 response = client.responses.create(
#       4     model="gpt-4.1-mini",
#       5     instructions="You are a helpful assistant that explains things clearly and concisely.",
#       6     input="Explain how neural networks work in simple terms."
#       7 )
#       9 print(response.output[0].content[0].text)
#
# AttributeError: 'OpenAIClient' object has no attribute 'responses'
