# %% [markdown]
# # Jupyter-Base example
#
# This notebook imports the editable `jupyter_base` package installed by PDM—no `sys.path` hacks.
#
# Use the **Python (jupyter-base)** kernel (`make install` registers it). If `import jupyter_base` fails, switch the kernel away from system Python.

# %%
from jupyter_base import load_settings, run_example_pipeline

settings = load_settings()
result = run_example_pipeline(settings, "Notebook demo")
result.to_dict()
# Out:
# {'label': 'demo:notebook-demo',
#  'success': True,
#  'finished_at': '2026-04-05T15:13:14.286667+00:00',
#  'tasks': [{'name': 'load_settings', 'ok': True, 'detail': 'app=jupyter-base'},
#   {'name': 'normalize_topic', 'ok': True, 'detail': 'notebook-demo'},
#   {'name': 'environment', 'ok': True, 'detail': 'development'}]}
